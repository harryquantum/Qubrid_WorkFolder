# %% [markdown]
# Dependencies and pacakges
# - python3
# - pip pacakges - cirq, qsimcirq, cuquantum

# %%
try:
    import cirq
except ImportError:
    print("installing cirq...")
    # !pip install --quiet cirq
    print("installed cirq.")
    import cirq

# %% [markdown]
# # Variational Quantum Eigensolver(VQE) using cuStateVec
#
# Materials adopted from:
# [https://quantumai.google/cirq/experiments/variational_algorithm](https://quantumai.google/cirq/experiments/variational_algorithm)

# %% [markdown]
# # Define the ansatz
#
# Generate a random Ising Hamiltonian on a square grid
#
# # $H=\sum_{\langle i,j \rangle} J_{i,j} Z_i Z_j + \sum_i h_iZ_i$

# %%
import cirq
import qsimcirq
import time
import copy
import random

# %%
import random
def rand2d(rows, cols):
    return [[random.choice([+1, -1]) for _ in range(cols)] for _ in range(rows)]

def random_instance(length):
    # transverse field terms
    h = rand2d(length, length)
    # links within a row
    jr = rand2d(length - 1, length)
    # links within a column
    jc = rand2d(length, length - 1)
    return (h, jr, jc)

h, jr, jc = random_instance(3)

# %%
print(f'transverse fields: {h}')
print(f'row j fields: {jr}')
print(f'column j fields: {jc}')
# Out:
# transverse fields: [[1, -1, -1], [1, -1, 1], [-1, -1, 1]]
# row j fields: [[-1, -1, -1], [-1, 1, -1]]
# column j fields: [[-1, 1], [-1, 1], [-1, -1]]

# %% [markdown]
# ### Prepare plus state

# %%
def prepare_plus_layer(length):
    for i in range(length):
        for j in range(length):
            yield cirq.H(cirq.GridQubit(i, j))

# %%
circuit = cirq.Circuit()
circuit.append(prepare_plus_layer(2))
print(circuit)
# Out:
# (0, 0): ───H───
#
# (0, 1): ───H───
#
# (1, 0): ───H───
#
# (1, 1): ───H───

# %% [markdown]
# ## X layer

# %%
def rot_x_layer(length, half_turns):
    """Yields X rotations by half_turns on a square grid of given length."""

    # Define the gate once and then re-use it for each Operation.
    rot = cirq.XPowGate(exponent=half_turns)

    # Create an X rotation Operation for each qubit in the grid.
    for i in range(length):
        for j in range(length):
            yield rot(cirq.GridQubit(i, j))

# %%
# Create the circuit using the rot_x_layer generator
circuit = cirq.Circuit()
circuit.append(rot_x_layer(2, 0.1))
print(circuit)
# Out:
# (0, 0): ───X^0.1───
#
# (0, 1): ───X^0.1───
#
# (1, 0): ───X^0.1───
#
# (1, 1): ───X^0.1───

# %% [markdown]
# ## Z layer

# %%
def rot_z_layer(h, half_turns):
    """Yields Z rotations by half_turns conditioned on the field h."""
    gate = cirq.ZPowGate(exponent=half_turns)
    for i, h_row in enumerate(h):
        for j, h_ij in enumerate(h_row):
            if h_ij == 1:
                yield gate(cirq.GridQubit(i, j))

# %%
circuit = cirq.Circuit()
circuit.append(rot_z_layer(h, 0.1))
print(circuit)
# Out:
# (0, 0): ───Z^0.1───
#
# (1, 0): ───Z^0.1───
#
# (1, 2): ───Z^0.1───
#
# (2, 2): ───Z^0.1───

# %% [markdown]
# ## Entangling Layer

# %% [markdown]
# Apply a `cirq.CZPowGate` for the same parameter between all qubits where the coupling field term $J$ is $+1$. If the field is $-1$, apply `cirq.CZPowGate` conjugated by $X$ gates on all qubits.

# %%
def rot_11_layer(jr, jc, half_turns):
    """Yields rotations about |11> conditioned on the jr and jc fields."""
    cz_gate = cirq.CZPowGate(exponent=half_turns)    
    for i, jr_row in enumerate(jr):
        for j, jr_ij in enumerate(jr_row):
            q = cirq.GridQubit(i, j)
            q_1 = cirq.GridQubit(i + 1, j)
            if jr_ij == -1:
                yield cirq.X(q)
                yield cirq.X(q_1)
            yield cz_gate(q, q_1)
            if jr_ij == -1:
                yield cirq.X(q)
                yield cirq.X(q_1)

    for i, jc_row in enumerate(jc):
        for j, jc_ij in enumerate(jc_row):
            q = cirq.GridQubit(i, j)
            q_1 = cirq.GridQubit(i, j + 1)
            if jc_ij == -1:
                yield cirq.X(q)
                yield cirq.X(q_1)
            yield cz_gate(q, q_1)
            if jc_ij == -1:
                yield cirq.X(q)
                yield cirq.X(q_1)

# %% [markdown]
# ## Put it all together to generate the ansatz
#
# 5x5 grid - 25 qubits simulation

# %%
#define a 5x5 qubit ansatz

length=5
qubits=cirq.GridQubit.square(length)
h, jr, jc = random_instance(length)

circuit = cirq.Circuit()
circuit.append(prepare_plus_layer(length))
circuit.append(rot_z_layer(h,0.3))
circuit.append(rot_11_layer(jr,jc,0.3))
circuit.append(rot_x_layer(length, 0.3))
circuit.append(cirq.measure(*qubits, key='x'))

# %%
print(circuit)
# Out:
#                        ┌───────────┐   ┌────────────────────┐   ┌──────────┐   ┌───────────────┐   ┌───────────────┐   ┌───────────────┐   ┌──────────┐           ┌──────┐
# (0, 0): ───H───Z^0.3────@───────────────────────────────────────────────────────@───────────────────X^0.3────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────M('x')───
#                         │                                                       │                                                                                                                                                                                    │
# (0, 1): ───H───X────────┼───────────────@────────────────────────X──────────────@^0.3───────────────@───────────────────X^0.3────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────M────────
#                         │               │                                                           │                                                                                                                                                                │
# (0, 2): ───H───X────────┼───────────────┼────@───────────────────X──────────────────────────────────@^0.3───────────────@───────────────────X^0.3────────────────────────────────────────────────────────────────────────────────────────────────────────────────────M────────
#                         │               │    │                                                                          │                                                                                                                                            │
# (0, 3): ───H───X────────┼────@──────────┼────┼────X─────────────────────────────────────────────────────────────────────@^0.3───────────────X─────────────@────────X─────────X^0.3───────────────────────────────────────────────────────────────────────────────────M────────
#                         │    │          │    │                                                                                                            │                                                                                                          │
# (0, 4): ───H───Z^0.3────┼────┼────X─────┼────┼────@──────────────X──────────────X─────────────────────────────────────────────────────────────────────────@^0.3────X─────────X^0.3───────────────────────────────────────────────────────────────────────────────────M────────
#                         │    │          │    │    │                                                                                                                                                                                                                  │
# (1, 0): ───H────────────@^0.3┼──────────┼────┼────┼────@─────────X──────────────────────────────────────────────────────@───────────────────X─────────────X^0.3──────────────────────────────────────────────────────────────────────────────────────────────────────M────────
#                              │          │    │    │    │                                                                │                                                                                                                                            │
# (1, 1): ───H───Z^0.3────X────┼──────────@^0.3┼────┼────┼─────────X──────────────@───────────────────X───────────────────@^0.3───────────────X─────────────X────────@─────────X───────X^0.3───────────────────────────────────────────────────────────────────────────M────────
#                              │               │    │    │                        │                                                                                  │                                                                                                 │
# (1, 2): ───H───Z^0.3────X────┼───────────────@^0.3┼────┼─────────X──────────────┼────@──────────────X──────────────────────────────────────────────────────────────@^0.3─────X───────@───────X^0.3───────────────────────────────────────────────────────────────────M────────
#                              │                    │    │                        │    │                                                                                               │                                                                               │
# (1, 3): ───H───X─────────────@^0.3──────X─────────┼────┼──────────────@─────────┼────┼───────────────────────────────────────────────────────────────────────────────────────────────@^0.3───X───────@───────X───────X^0.3───────────────────────────────────────────M────────
#                                                   │    │              │         │    │                                                                                                               │                                                               │
# (1, 4): ───H───X──────────────────────────────────@^0.3┼─────────X────┼─────────┼────┼────@─────────X────────────────────────────────────────────────────────────────────────────────────────────────@^0.3───X───────X^0.3───────────────────────────────────────────M────────
#                                                        │              │         │    │    │                                                                                                                                                                          │
# (2, 0): ───H───Z^0.3───────────────────────────────────@^0.3─────@────┼─────────┼────┼────┼─────────────────────────────@───────────────────X^0.3────────────────────────────────────────────────────────────────────────────────────────────────────────────────────M────────
#                                                                  │    │         │    │    │                             │                                                                                                                                            │
# (2, 1): ───H─────────────────────────────────────────────────────┼────┼─────────@^0.3┼────┼─────────@───────────────────@^0.3───────────────@─────────────X^0.3──────────────────────────────────────────────────────────────────────────────────────────────────────M────────
#                                                                  │    │              │    │         │                                       │                                                                                                                        │
# (2, 2): ───H─────────────────────────────────────────────────────┼────┼──────────────@^0.3┼─────────┼────@──────────────────────────────────@^0.3─────────X────────@─────────X───────X^0.3───────────────────────────────────────────────────────────────────────────M────────
#                                                                  │    │                   │         │    │                                                         │                                                                                                 │
# (2, 3): ───H─────────────────────────────────────────────────────┼────@^0.3─────@─────────┼─────────┼────┼────X────────────────────────────────────────────────────@^0.3─────X───────@───────X^0.3───────────────────────────────────────────────────────────────────M────────
#                                                                  │              │         │         │    │                                                                           │                                                                               │
# (2, 4): ───H───Z^0.3─────────────────────────────────────────────┼──────────────┼─────────@^0.3─────┼────┼────X─────────@───────────────────X────────────────────────────────────────@^0.3───X^0.3───────────────────────────────────────────────────────────────────M────────
#                                                                  │              │                   │    │              │                                                                                                                                            │
# (3, 0): ───H─────────────────────────────────────────────────────@^0.3──────────┼────X──────────────┼────┼────@─────────┼────X─────────────────────────────────────@─────────X^0.3───────────────────────────────────────────────────────────────────────────────────M────────
#                                                                                 │                   │    │    │         │                                          │                                                                                                 │
# (3, 1): ───H───Z^0.3────────────────────────────────────────────────────────────┼───────────────────@^0.3┼────┼─────────┼────X───────────────────@────────X────────@^0.3─────X───────@───────X───────X^0.3───────────────────────────────────────────────────────────M────────
#                                                                                 │                        │    │         │                        │                                   │                                                                               │
# (3, 2): ───H───Z^0.3────────────────────────────────────────────────────────────┼────────────────────────@^0.3┼─────────┼────@──────────────X────┼───────────────────────────────────@^0.3───X───────@───────X^0.3───────────────────────────────────────────────────M────────
#                                                                                 │                             │         │    │                   │                                                   │                                                               │
# (3, 3): ───H───Z^0.3────────────────────────────────────────────────────────────@^0.3───────────────X─────────┼─────────┼────┼────@─────────X────┼───────────────────────────────────────────────────@^0.3───@───────X^0.3───────────────────────────────────────────M────────
#                                                                                                               │         │    │    │              │                                                           │                                                       │
# (3, 4): ───H───X──────────────────────────────────────────────────────────────────────────────────────────────┼─────────@^0.3┼────┼─────────X────┼────────X────────@─────────X───────────────────────────────@^0.3───X^0.3───────────────────────────────────────────M────────
#                                                                                                               │              │    │              │                 │                                                                                                 │
# (4, 0): ───H───X──────────────────────────────────────────────────────────────────────────────────────────────@^0.3─────X────┼────┼─────────X────┼─────────────────┼─────────@───────X───────X^0.3───────────────────────────────────────────────────────────────────M────────
#                                                                                                                              │    │              │                 │         │                                                                                       │
# (4, 1): ───H───Z^0.3────X────────────────────────────────────────────────────────────────────────────────────────────────────┼────┼──────────────@^0.3────X────────┼────X────@^0.3───X───────X───────@───────X───────X^0.3───────────────────────────────────────────M────────
#                                                                                                                              │    │                                │                                 │                                                               │
# (4, 2): ───H─────────────────────────────────────────────────────────────────────────────────────────────────────────────────@^0.3┼─────────X──────────────────────┼─────────────────────────────────@^0.3───X───────X───────@───────X───X^0.3───────────────────────M────────
#                                                                                                                                   │                                │                                                         │                                       │
# (4, 3): ───H───Z^0.3────X─────────────────────────────────────────────────────────────────────────────────────────────────────────@^0.3─────X─────────────X────────┼─────────────────────────────────────────────────────────@^0.3───X───X───────@───────X───X^0.3───M────────
#                                                                                                                                                                    │                                                                             │                   │
# (4, 4): ───H───X───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────@^0.3─────X───────X───────────────────────────────────────────────────────────@^0.3───X───X^0.3───M────────
#                        └───────────┘   └────────────────────┘   └──────────┘   └───────────────┘   └───────────────┘   └───────────────┘   └──────────┘           └──────┘

# %% [markdown]
# # Run the simualation

# %%
# # Define the simulators
# # Default simulator
simulator = cirq.Simulator()

# cuQuantum enabled GPU simulator
ngpus = 1
qsim_options = qsimcirq.QSimOptions(
    max_fused_gate_size = 2,
    cpu_threads = 1,
    gpu_mode = ngpus,
    # use_sampler = True,
    disable_gpu = False
)

simulator_cuQ = qsimcirq.QSimSimulator(qsim_options)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 7
#       5 # cuQuantum enabled GPU simulator
#       6 ngpus = 1
# ----> 7 qsim_options = qsimcirq.QSimOptions(
#       8     max_fused_gate_size = 2,
#       9     cpu_threads = 1,
#      10     gpu_mode = ngpus,
#      11     # use_sampler = True,
#      12     disable_gpu = False
#      13 )
#      15 simulator_cuQ = qsimcirq.QSimSimulator(qsim_options)
#
# TypeError: QSimOptions.__init__() got an unexpected keyword argument 'disable_gpu'

# %%
# Define the simulators
# Default simulator
simulator = cirq.Simulator()

# cuQuantum enabled GPU simulator
ngpus=1
qsim_options=qsimcirq.QSimOptions(
    max_fused_gate_size=2,
    cpu_threads=1,
    gpu_mode=ngpus
)
simulator_cuQ=qsimcirq.QSimSimulator(qsim_options)

# %%
# Default simulator
start=time.time()
results = simulator.run(circuit, repetitions=100)
print(results.histogram(key='x'))
# Out:
# Counter({29824339: 1, 19040736: 1, 16930850: 1, 18380753: 1, 22153384: 1, 16979652: 1, 4247448: 1, 1450257: 1, 1558912: 1, 954536: 1, 16961750: 1, 8880592: 1, 8570180: 1, 8888916: 1, 17248416: 1, 692809: 1, 10958865: 1, 11413633: 1, 2787025: 1, 19554481: 1, 21565528: 1, 9319016: 1, 985184: 1, 610545: 1, 17914135: 1, 4217360: 1, 18031732: 1, 14559553: 1, 18008216: 1, 19038656: 1, 19740228: 1, 17469777: 1, 18254130: 1, 17438020: 1, 19289424: 1, 17346800: 1, 9834791: 1, 2560436: 1, 3019856: 1, 30486704: 1, 2245764: 1, 2032884: 1, 6760352: 1, 19268817: 1, 1261968: 1, 21446800: 1, 479316: 1, 86768: 1, 594673: 1, 991400: 1, 9836373: 1, 17113776: 1, 4730012: 1, 5807060: 1, 5465280: 1, 18557106: 1, 17224020: 1, 328098: 1, 833745: 1, 8864713: 1, 4229824: 1, 19026352: 1, 17975972: 1, 3014996: 1, 19796548: 1, 18289737: 1, 10681408: 1, 18064597: 1, 2531464: 1, 21898312: 1, 721538: 1, 19800224: 1, 16943445: 1, 11037393: 1, 19858643: 1, 21146178: 1, 9836592: 1, 333504: 1, 11157904: 1, 1774940: 1, 30494884: 1, 402624: 1, 18902232: 1, 16861329: 1, 19345440: 1, 3081160: 1, 16865066: 1, 9639104: 1, 8817422: 1, 9361488: 1, 21082944: 1, 11077796: 1, 18942099: 1, 17395872: 1, 5603541: 1, 2073746: 1, 402625: 1, 5854345: 1, 2708565: 1, 10148113: 1})

# %%
print("CPU runtime: {:.2f}s".format(time.time() - start))
# Out:
# CPU runtime: 9.55s

# %%
# cuQuantum backend

start=time.time()
results = simulator_cuQ.run(circuit, repetitions=100)
print(results.histogram(key='x'))
print("GPU runtime: {:.2f}s".format(time.time() - start))
# Out:
# Counter({213024: 1, 595144: 1, 656497: 1, 665752: 1, 704680: 1, 725312: 1, 757936: 1, 886980: 1, 988234: 1, 1156736: 1, 1182856: 1, 1263670: 1, 1507792: 1, 1782402: 1, 2250800: 1, 2449119: 1, 2560928: 1, 2676912: 1, 2698377: 1, 2819275: 1, 2844380: 1, 3033760: 1, 3037584: 1, 4247744: 1, 4725005: 1, 4820226: 1, 4883649: 1, 4892112: 1, 5067120: 1, 5576021: 1, 5954567: 1, 6170804: 1, 7428673: 1, 8078544: 1, 9113715: 1, 9120945: 1, 9373856: 1, 10294368: 1, 10562208: 1, 10601369: 1, 10671440: 1, 10818256: 1, 11084992: 1, 11151941: 1, 11216022: 1, 14616457: 1, 14945232: 1, 15078050: 1, 15090080: 1, 15618198: 1, 16848565: 1, 16863530: 1, 16864329: 1, 16898057: 1, 16979153: 1, 16996189: 1, 17060016: 1, 17077056: 1, 17189267: 1, 17256512: 1, 17437024: 1, 17500832: 1, 17501332: 1, 17504470: 1, 17506544: 1, 17781973: 1, 17973680: 1, 18043073: 1, 18420673: 1, 18960817: 1, 18968721: 1, 19010880: 1, 19012192: 1, 19024001: 1, 19026241: 1, 19027152: 1, 19034432: 1, 19043403: 1, 19076276: 1, 19096777: 1, 19268800: 1, 19286184: 1, 19338440: 1, 19350744: 1, 20108754: 1, 20459956: 1, 21047424: 1, 21058884: 1, 21291208: 1, 21314768: 1, 21645472: 1, 21662303: 1, 22098000: 1, 24062098: 1, 27697252: 1, 28755082: 1, 29415632: 1, 29754505: 1, 29786761: 1, 31797364: 1})
# GPU runtime: 1.84s

# %% [markdown]
# # Calculate the energy expectation

# %%
import numpy as np

def energy_func(length, h, jr, jc):
    def energy(measurements):
        # Reshape measurement into array that matches grid shape.
        meas_list_of_lists = [measurements[i * length:(i + 1) * length]
                              for i in range(length)]
        # Convert true/false to +1/-1.
        pm_meas = 1 - 2 * np.array(meas_list_of_lists).astype(np.int32)

        tot_energy = np.sum(pm_meas * h)
        for i, jr_row in enumerate(jr):
            for j, jr_ij in enumerate(jr_row):
                tot_energy += jr_ij * pm_meas[i, j] * pm_meas[i + 1, j]
        for i, jc_row in enumerate(jc):
            for j, jc_ij in enumerate(jc_row):
                tot_energy += jc_ij * pm_meas[i, j] * pm_meas[i, j + 1]
        return tot_energy
    return energy

def obj_func(result):
    energy_hist = result.histogram(key='x', fold_func=energy_func(length, h, jr, jc))
    return np.sum([k * v for k,v in energy_hist.items()]) / result.repetitions

# %%
print(results.histogram(key='x', fold_func=energy_func(length, h, jr, jc)))
print(f'Value of the objective function {obj_func(results)}')
# Out:
# Counter({9: 18, 7: 16, 11: 10, 15: 7, 5: 7, -3: 6, -1: 6, 13: 6, 1: 5, 3: 4, 25: 3, 19: 2, 21: 2, 17: 2, -11: 2, -5: 1, -9: 1, -7: 1, 23: 1})
# Value of the objective function 7.64

# %% [markdown]
# # Parametrize the ansatz to minimize the energy

# %%
import sympy

# Define the parameters symbolically
circuit = cirq.Circuit()
alpha = sympy.Symbol('alpha')
beta = sympy.Symbol('beta')
gamma = sympy.Symbol('gamma')

# Define the circuit
circuit= cirq.Circuit()
circuit.append(prepare_plus_layer(length))
circuit.append(rot_z_layer(h,alpha))
circuit.append(rot_11_layer(jr, jc, beta))
circuit.append(rot_x_layer(length, gamma))
circuit.append(cirq.measure(*qubits, key='x'))

print(circuit)
# Out:
#                ┌───────────────────┐   ┌─────────────┐   ┌────────────────────────┐            ┌────────────────────────┐   ┌─────────────┐   ┌────────────────────┐   ┌─────────────┐             ┌────────┐
# (0, 0): ───H───────────@────────────────X─────────────────────────────────────────────@─────────X────────────────────────────X^gamma───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────M('x')───
#                        │                                                              │                                                                                                                                                                                                            │
# (0, 1): ───H────Z^alpha┼────────────────@─────────────────X───────────────────────────@^beta────X────────────────────────────@─────────────────X^gamma─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────M────────
#                        │                │                                                                                    │                                                                                                                                                                     │
# (0, 2): ───H────Z^alpha┼────────────────┼─────X───────────@───────────────────────────X──────────────────────────────────────@^beta────────────@────────────────────────X^gamma────────────────────────────────────────────────────────────────────────────────────────────────────────────────────M────────
#                        │                │                 │                                                                                    │                                                                                                                                                   │
# (0, 3): ───H───────────┼─────@──────────┼─────────────────┼────────────────────────────────────────────────────────────────────────────────────@^beta───────────────────X────────────────@──────────X───────────X^gamma────────────────────────────────────────────────────────────────────────────M────────
#                        │     │          │                 │                                                                                                                              │                                                                                                         │
# (0, 4): ───H────Z^alpha┼─────┼──────────┼─────@───────────┼─────X────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────@^beta─────X───────────X^gamma────────────────────────────────────────────────────────────────────────────M────────
#                        │     │          │     │           │                                                                                                                                                                                                                                        │
# (1, 0): ───H───────────@^beta┼──────────┼─────┼─────X─────┼─────@─────────────────────X─────────@────────────────────────────X^gamma───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────M────────
#                              │          │     │           │     │                               │                                                                                                                                                                                                  │
# (1, 1): ───H────Z^alpha──────┼──────────@^beta┼───────────┼─────┼─────@─────────────────────────@^beta──────────────────────────────────────────────────────────────────@────────────────X^gamma───────────────────────────────────────────────────────────────────────────────────────────────────M────────
#                              │                │           │     │     │                                                                                                 │                                                                                                                          │
# (1, 2): ───H────X────────────┼────────────────┼───────────@^beta┼─────┼───────────────X─────────X────────────────────────────@─────────────────X────────────────────────@^beta───────────X──────────@───────────X─────────X^gamma──────────────────────────────────────────────────────────────────M────────
#                              │                │                 │     │                                                      │                                                                      │                                                                                              │
# (1, 3): ───H─────────────────@^beta─────X─────┼───────────@─────┼─────┼───────────────X─────────X────────────────────────────┼──────────────────────────────────────────────────────────────────────@^beta──────X─────────@─────────X^gamma────────────────────────────────────────────────────────M────────
#                                               │           │     │     │                                                      │                                                                                            │                                                                        │
# (1, 4): ───H──────────────────────────────────@^beta──────┼─────┼─────┼─────@────────────────────────────────────────────────┼────────────────────────────────────────────────────────────────────────────────────────────@^beta────X^gamma────────────────────────────────────────────────────────M────────
#                                                           │     │     │     │                                                │                                                                                                                                                                     │
# (2, 0): ───H────Z^alpha─────────────────X─────────────────┼─────@^beta┼─────┼─────────X─────────@────────────────────────────┼──────X───────────────────────────────────@────────────────X──────────X^gamma────────────────────────────────────────────────────────────────────────────────────────M────────
#                                                           │           │     │                   │                            │                                          │                                                                                                                          │
# (2, 1): ───H────Z^alpha───────────────────────────────────┼───────────@^beta┼─────────X─────────┼─────@──────────────────────┼──────X──────────X────────────────────────@^beta───────────X──────────@───────────X^gamma────────────────────────────────────────────────────────────────────────────M────────
#                                                           │                 │                   │     │                      │                                                                      │                                                                                              │
# (2, 2): ───H────X─────────────────────────────────────────┼─────────────────┼───────────────────┼─────┼──────────────────────@^beta────────────X────────────────────────@───────────────────────────@^beta──────X─────────@─────────X─────────X^gamma──────────────────────────────────────────────M────────
#                                                           │                 │                   │     │                                                                 │                                                 │                                                                        │
# (2, 3): ───H────Z^alpha─────────────────X─────────────────@^beta────────────┼─────────X─────────┼─────┼─────@────────────────X──────────────────────────────────────────┼─────────────────────────────────────────────────@^beta────X─────────@─────────X^gamma────────────────────────────────────M────────
#                                                                             │                   │     │     │                                                           │                                                                     │                                                    │
# (2, 4): ───H────────────────────────────────────────────────────────────────@^beta────X─────────┼─────┼─────┼─────@──────────X──────────────────────────────────────────┼─────────────────────────────────────────────────────────────────────@^beta────X^gamma────────────────────────────────────M────────
#                                                                                                 │     │     │     │                                                     │                                                                                                                          │
# (3, 0): ───H────Z^alpha─────────────────────────────────────────────────────────────────────────@^beta┼─────┼─────┼─────────────────@───────────────────────────────────┼──────@─────────X^gamma───────────────────────────────────────────────────────────────────────────────────────────────────M────────
#                                                                                                       │     │     │                 │                                   │      │                                                                                                                   │
# (3, 1): ───H────Z^alpha─────────────────X─────────────────────────────────────────────────────────────@^beta┼─────┼──────────X──────┼──────────@────────────────────────┼──────@^beta────X──────────────────────────────────────────@─────────X─────────X^gamma────────────────────────────────────M────────
#                                                                                                             │     │                 │          │                        │                                                           │                                                              │
# (3, 2): ───H────────────────────────────────────────────────────────────────────────────────────────────────┼─────┼─────────────────┼──────────┼────────────────────────@^beta───────────X──────────@───────────X─────────X─────────@^beta────X─────────X─────────@────────X───X^gamma─────────────M────────
#                                                                                                             │     │                 │          │                                                    │                                                             │                                │
# (3, 3): ───H────────────────────────────────────────────────────────────────────────────────────────────────@^beta┼──────────X──────┼──────────┼──────@─────────────────X────────────────X──────────┼─────────────────────────────────────────────────────────────@^beta───X───@─────────X^gamma───M────────
#                                                                                                                   │                 │          │      │                                             │                                                                          │                   │
# (3, 4): ───H────X─────────────────────────────────────────────────────────────────────────────────────────────────@^beta─────X──────┼──────────┼──────┼─────@───────────────────────────────────────┼──────────────────────────────────────────────────────────────────────────@^beta────X^gamma───M────────
#                                                                                                                                     │          │      │     │                                       │                                                                                              │
# (4, 0): ───H────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────@^beta─────┼──────┼─────┼─────X──────────────────────@──────────┼──────X────X^gamma────────────────────────────────────────────────────────────────────────────M────────
#                                                                                                                                                │      │     │                            │          │                                                                                              │
# (4, 1): ───H────Z^alpha────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────@^beta─┼─────┼───────────X────────────────@^beta─────┼──────X──────────────@─────────X^gamma────────────────────────────────────────────────────────M────────
#                                                                                                                                                       │     │                                       │                     │                                                                        │
# (4, 2): ───H────Z^alpha─────────────────X─────────────────────────────────────────────────────────────────────────────────────────────────────────────┼─────┼───────────────────────────────────────@^beta──────X─────────@^beta────@─────────X^gamma──────────────────────────────────────────────M────────
#                                                                                                                                                       │     │                                                                       │                                                              │
# (4, 3): ───H────Z^alpha─────────────────X─────────────────────────────────────────────────────────────────────────────────────────────────────────────@^beta┼───────────X───────────────────────────────────────────────────────────@^beta────@─────────X^gamma────────────────────────────────────M────────
#                                                                                                                                                             │                                                                                 │                                                    │
# (4, 4): ───H────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────@^beta────────────────────────────────────────────────────────────────────────────@^beta────X^gamma────────────────────────────────────M────────
#                └───────────────────┘   └─────────────┘   └────────────────────────┘            └────────────────────────┘   └─────────────┘   └────────────────────┘   └─────────────┘             └────────┘

# %%
# Define the sweep size
sweep_size = 10
start=time.time()

sweep = (cirq.Linspace(key='alpha', start=0.0, stop=1.0, length=sweep_size)
         * cirq.Linspace(key='beta', start=0.0, stop=1.0, length=sweep_size)
         * cirq.Linspace(key='gamma', start=0.0, stop=1.0, length=sweep_size))

# Execute the sweep using cuQuantum
results = simulator_cuQ.run_sweep(circuit, params=sweep, repetitions=100)
print("runtime: {:.2f}s".format(time.time() - start))

min = None
min_params = None
for result in results:
    value = obj_func(result)
    if min is None or value < min:
        min = value
        min_params = result.params
print(f'Minimum objective value is {min}.')
# Out:
# runtime: 1723.31s
# Minimum objective value is -5.78.

# %%
# Execute the sweep using qsim
results = simulator.run_sweep(circuit, params=sweep, repetitions=100)
print("runtime: {:.2f}s".format(time.time() - start))

min = None
min_params = None
for result in results:
    value = obj_func(result)
    if min is None or value < min:
        min = value
        min_params = result.params
print(f'Minimum objective value is {min}.')
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3508, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_49023/1522435971.py", line 2, in <module>
#     results = simulator.run_sweep(circuit, params=sweep, repetitions=100)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/sim/simulator.py", line 72, in run_sweep
#     return list(self.run_sweep_iter(program, params, repetitions))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/sim/simulator.py", line 103, in run_sweep_iter
#     records = self._run(
#               ^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/sim/simulator_base.py", line 245, in _run
#     for step_result in self._core_iterator(circuit=prefix, sim_state=sim_state):
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/sim/simulator_base.py", line 220, in _core_iterator
#     protocols.act_on(op, sim_state)
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/protocols/act_on_protocol.py", line 153, in act_on
#     result = arg_fallback(action, qubits=qubits, allow_decompose=allow_decompose)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/sim/simulation_product_state.py", line 118, in _act_on_fallback_
#     protocols.act_on(action, op_args, act_on_qubits, allow_decompose=allow_decompose)
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/protocols/act_on_protocol.py", line 153, in act_on
#     result = arg_fallback(action, qubits=qubits, allow_decompose=allow_decompose)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/sim/state_vector_simulation_state.py", line 388, in _act_on_fallback_
#     result = strat(action, self, qubits)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/sim/state_vector_simulation_state.py", line 420, in _strat_act_on_state_vector_from_apply_unitary
#     if not args._state.apply_unitary(action, args.get_axes(qubits)):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/sim/state_vector_simulation_state.py", line 166, in apply_unitary
#     new_target_tensor = protocols.apply_unitary(
#                         ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/protocols/apply_unitary_protocol.py", line 395, in apply_unitary
#     result = strat(unitary_value, args)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/protocols/apply_unitary_protocol.py", line 482, in _strat_apply_unitary_from_unitary
#     return _apply_unitary_from_matrix(matrix, unitary_value, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/protocols/apply_unitary_protocol.py", line 455, in _apply_unitary_from_matrix
#     sub_result = linalg.apply_matrix_to_slices(
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/cirq/linalg/transformations.py", line -1, in apply_matrix_to_slices
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2105, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1428, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1319, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1172, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1087, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/IPython/core/ultratb.py", line 969, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/IPython/core/ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/stack_data/core.py", line 734, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/stack_data/core.py", line 681, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/stack_data/core.py", line 660, in executing_piece
#     return only(
#            ^^^^^
#   File "/home/harryneo/anaconda3/envs/nvidia_quantum/lib/python3.11/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
